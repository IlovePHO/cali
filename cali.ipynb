# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
cities = pd.read_csv('./data/california_cities.csv')
cities.head()

cities["area_total_km2"].sort_values(ascending=False)
# Out:
# 239    1302.000
# 367     964.510
# 55      527.401
# 375     466.109
# 26      371.946
#          ...
# 163         NaN
# 237         NaN
# 370         NaN
# 393         NaN
# 443         NaN
# Name: area_total_km2, Length: 482, dtype: float64

# %%
# Extract Latb and Longd

lat, lon = cities['latd'], cities ['longd']
population, area = cities['population_total'], cities['area_total_km2']

plt.style.use("classic")
plt.figure(figsize=(8,6))
# Plot using Pylot API
plt.scatter(lon, lat,
            c=np.log10(population), cmap='viridis',
            s=area, linewidths=0, alpha=0.5) 

plt.axis('equal')
plt.xlabel('longlatutude')
plt.ylabel('latitude');
plt.colorbar(label='log_{19}$(population)')
plt.clim(3,7)

# Creat a legend for cities'sizes
area_range = [50, 100, 300, 500]

for area in area_range:
  plt.scatter([], [], s =area, c='k', alpha=0.4,
              label=str(area) + ' km$^2$')
  plt.legend(scatterpoints=1, labelspacing=1, title='City Area')

plt.title('California Cities: Population and Area Distributions');
